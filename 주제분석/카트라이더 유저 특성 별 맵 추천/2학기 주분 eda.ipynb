# %%
import numpy as np
import pandas as pd

# %%
train=pd.read_csv('개편이전스피드.csv',encoding = 'ANSI')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig,axs=plt.subplots(figsize=(7,7))
ratio=[7304,7655,16931]
labels=['S','M','L']
patches,texts,pcts=plt.pie(x=ratio,labels=labels,autopct='%.1f%%',shadow=True,startangle=15,colors=(['#D8D9FB','#F5CBC7','#C7EDE7']), explode=([0.05,0.05,0.07]),textprops={'fontsize': 17})
plt.setp(pcts,color='black',fontweight='bold')
# Out:
# [None, None, None, None, None, None]

# %%
fig,axs=plt.subplots(figsize=(7,7))
ratio=[0.2995923486986516,0.23552837880213234,0.46487927249921607]
labels=['Speed','Item','Both']
patches,texts,pcts=plt.pie(x=ratio,labels=labels,autopct='%.1f%%',shadow=True,startangle=15,colors=(['#E5F59A','#FAEB91','#DED981']), explode=([0.05,0.05,0.07]),textprops={'fontsize': 17})
plt.setp(pcts,color='black',fontweight='bold')
# Out:
# [None, None, None, None, None, None]

# %%
fig,axs=plt.subplots(figsize=(7,7))
ratio=[0.24666039510818438,0.2149576669802446,0.5383819379115711]
labels=['Team','Solo','Both']
patches,texts,pcts=plt.pie(x=ratio,labels=labels,autopct='%.1f%%',shadow=True,startangle=15,colors=(['#FAE8CF','#F5EEE1','#E3CFAE']), explode=([0.05,0.05,0.07]),textprops={'fontsize': 17})
plt.setp(pcts,color='black',fontweight='bold')
# Out:
# [None, None, None, None, None, None]

# %%
train
# Out:
#    Unnamed: 0  gameSpeed       n
# 0           1          1  242090
# 1           2          2  312778
# 2           3          4  468403
# 3           4          7  994190

# %%
fig,axs=plt.subplots(figsize=(7,7))
ratio=[242090,312778,468403,994190]
labels=['1','2','4','7']
patches,texts,pcts=plt.pie(x=ratio,labels=labels,autopct='%.1f%%',shadow=True,startangle=15,colors=(['#FCEBA7','#FCEC83','#FFE565','#FFDA7E']), explode=([0.05,0.05,0.05,0.05]),textprops={'fontsize': 17})
plt.setp(pcts,color='black',fontweight='bold')
# Out:
# [None, None, None, None, None, None, None, None]

# %%
plt.rc('font', family='NanumGothic')
fig,axs=plt.subplots(figsize=(7,7))
ratio=[31,27.2,13,16.6,12.2]
labels=['장갑','별장갑','스타','메달','만렙']
patches,texts,pcts=plt.pie(x=ratio,labels=labels,autopct='%.1f%%',shadow=True,startangle=15,colors=(['#FCDEE4','#D2F7E9','#FDEC94','#D0FDBB','#D9D4EE']), explode=([0.05,0.05,0.05,0.05,0.05]),textprops={'fontsize': 17})
plt.setp(pcts,color='black',fontweight='bold')
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
plt.rc('font', family='NanumGothic')
fig,axs=plt.subplots(figsize=(7,7))
ratio=[14.4,23.2,14.4,23,25]
labels=['장갑','별장갑','스타','메달','만렙']
patches,texts,pcts=plt.pie(x=ratio,labels=labels,autopct='%.1f%%',shadow=True,startangle=15,colors=(['#FCDEE4','#D2F7E9','#FDEC94','#D0FDBB','#D9D4EE']), explode=([0.05,0.05,0.05,0.05,0.05]),textprops={'fontsize': 17})
plt.setp(pcts,color='black',fontweight='bold')
# Out:
# [None, None, None, None, None, None, None, None, None, None]

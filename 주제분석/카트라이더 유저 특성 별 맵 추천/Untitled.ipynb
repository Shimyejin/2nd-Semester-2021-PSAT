# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('final_map.csv',encoding='ANSI')

# %%
data.head()
# Out:
#                 맵이름        스개        스팀        아개        아팀  스피드 개인전  스피드 팀전  \
# 0     공동묘지 유령의 계곡 R  0.281321  0.250000  0.351488  0.374398    141.0    66.0
# 1     공동묘지 해골 손가락 R  0.308462  0.458333  0.000000  0.000000     57.0    22.0
# 2        광산 보석채굴장 R  0.391304  0.276000  0.322701  0.450526     46.0    16.0
# 3     광산 뽀글뽀글 용암굴 R  0.215397  0.187500  0.232863  0.343667    192.0    82.0
# 4  노르테유 부스터존 점령작전 R  0.165000  0.273333  0.041250  0.030000      8.0    32.0
#
#    아이템 개인전   아이템 팀전     리타이어율  ...  난이도  랩  트랙 길이(km)  진행 방향  AI 주행  \
# 0   2612.0   2924.0  0.314302  ...    3  3        7.5    반시계      1
# 1      NaN      NaN  0.191699  ...    3  3        6.3    반시계      0
# 2   6115.0  14408.0  0.360133  ...    3  3        7.5    반시계      1
# 3   2379.0   3070.0  0.244857  ...    3  3        5.4    반시계      1
# 4     20.0     16.0  0.127396  ...    2  3        6.6    반시계      0
#
#           특징  지름길개수 부스터발판개수  커브개수  유턴개수
# 0  very hard      3       0     6     0
# 1        NaN      4       0     1     9
# 2  very hard      1       0     7     1
# 3  very hard      0       0     4     1
# 4        NaN      0       5     7     0
#
# [5 rows x 22 columns]

# %%
data = data.sort_values(by=['스피드 개인전'], axis=0,ascending=False)

# %%
new = data[0:20]
new
# Out:
#                 맵이름   스피드 개인전    스피드 팀전  아이템 개인전   아이템 팀전  리타이어율    완주율    스개  \
# 135          빌리지 운하  100357.0  193558.0  31481.0   9628.0  0.230  0.770  0.31
# 242            트랙 9   84774.0   15458.0      NaN      NaN  0.525  0.475  0.37
# 114      빌리지 고가의 질주   57152.0   69500.0      NaN      NaN  0.130  0.870  0.17
# 240  코리아 제주 해오름 다운힐   43767.0   32620.0      NaN      NaN  0.135  0.865  0.15
# 113      비치 해변 드라이브   38726.0   43355.0      NaN      NaN  0.140  0.860  0.17
# 57     노르테유 허공의 갈림길   33461.0    5184.0  31011.0  21926.0  0.470  0.530  0.31
# 38      네모 산타의 비밀공간   31181.0   40110.0      NaN      NaN  0.280  0.720  0.30
# 223      차이나 서안 병마용   30596.0   48934.0      NaN      NaN  0.265  0.735  0.28
# 7        WKC 코리아 서킷   29302.0   33731.0      NaN      NaN  0.115  0.885  0.15
# 200       월드 리오 다운힐   28828.0   30480.0      NaN      NaN  0.165  0.835  0.19
# 197       월드 뉴욕 대질주   27674.0   34412.0      NaN      NaN  0.195  0.805  0.22
# 162       신화 신들의 세계   26599.0   32672.0      NaN      NaN  0.135  0.865  0.17
# 198     월드 두바이 다운타운   26304.0   38110.0      NaN      NaN  0.210  0.790  0.24
# 39      네모 장난감 선물공장   23967.0   28426.0      NaN      NaN  0.220  0.780  0.24
# 117          빌리지 남산   23923.0   33890.0      NaN      NaN  0.140  0.860  0.18
# 235     코리아 다이나믹 서울   23098.0   31458.0      NaN      NaN  0.320  0.680  0.31
# 211       쥐라기 공룡 무덤   21204.0   30552.0      NaN      NaN  0.185  0.815  0.25
# 194     올림포스 제우스 시티   20777.0   30196.0      NaN      NaN  0.400  0.600  0.39
# 228          차이나 황산   20399.0   28548.0      NaN      NaN  0.205  0.795  0.23
# 104     브로디 비밀의 연구소   19933.0   31090.0      NaN      NaN  0.225  0.775  0.25
#
#        스팀    아개  ...  난이도  랩  트랙 길이(km)  진행 방향  AI 주행    특징  지름길개수 부스터발판개수  \
# 135  0.07  0.31  ...    1  3        4.8     시계      1   NaN    0.0     0.0
# 242  0.68   NaN  ...    2  1        3.5    단선형      1   NaN    0.0     0.0
# 114  0.09   NaN  ...    2  2        7.4     시계      1   NaN    0.0     0.0
# 240  0.12   NaN  ...    2  1        5.6    단선형      1   NaN    2.0     1.0
# 113  0.11   NaN  ...    2  2        9.9    반시계      1   NaN    0.0     7.0
# 57   0.72  0.45  ...    2  3        3.9    반시계      1   NaN    1.0     3.0
# 38   0.26   NaN  ...    4  2        8.2    워프형      1   NaN    3.0     5.0
# 223  0.25   NaN  ...    4  2        7.4    반시계      1  hard    NaN     NaN
# 7    0.08   NaN  ...    2  2        8.7    반시계      1   NaN    0.0     0.0
# 200  0.14   NaN  ...    2  1        5.7    단선형      1   NaN    2.0     2.0
# 197  0.17   NaN  ...    3  1        6.9    단선형      1   NaN    5.0     1.0
# 162  0.10   NaN  ...    3  1        6.9    워프형      0   NaN    0.0     5.0
# 198  0.18   NaN  ...    3  2        8.4     시계      1   NaN    2.0     0.0
# 39   0.20   NaN  ...    3  1        6.2    단선형      1   NaN    4.0     6.0
# 117  0.10   NaN  ...    2  2        8.2     시계      1   NaN    1.0     0.0
# 235  0.33   NaN  ...    3  1        6.6     시계      1   NaN    2.0     0.0
# 211  0.12   NaN  ...    2  2        8.5    워프형      0   NaN    0.0     0.0
# 194  0.41   NaN  ...    3  2        8.0    반시계      1   NaN    1.0     0.0
# 228  0.18   NaN  ...    3  1        6.7    단선형      1   NaN    4.0     0.0
# 104  0.20   NaN  ...    3  2       10.5    워프형      0  hard    1.0     2.0
#
#      커브개수  유턴개수
# 135   5.0   0.0
# 242  19.0   0.0
# 114   9.0   3.0
# 240  14.0   3.0
# 113  14.0   0.0
# 57    4.0   1.0
# 38    8.0   3.0
# 223   NaN   NaN
# 7    12.0   6.0
# 200  18.0   2.0
# 197  27.0   1.0
# 162  10.0   5.0
# 198  15.0   0.0
# 39   20.0   4.0
# 117  14.0   2.0
# 235  17.0   1.0
# 211  12.0   0.0
# 194  21.0   3.0
# 228  16.0   5.0
# 104  12.0   5.0
#
# [20 rows x 22 columns]

# %%
plt.rcParams['font.family'] = 'NanumSquare'

# %%
import matplotlib.font_manager as fm

# 설치된 폰트 출력
font_list = [font.name for font in fm.fontManager.ttflist]
font_list
# Out:
# ['STIXSizeTwoSym',
#  'STIXSizeFiveSym',
#  'cmr10',
#  'DejaVu Sans',
#  'STIXSizeFourSym',
#  'cmex10',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'cmsy10',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Sans Display',
#  'DejaVu Sans',
#  'DejaVu Serif Display',
#  'cmtt10',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'DejaVu Sans',
#  'cmmi10',
#  'DejaVu Serif',
#  'cmss10',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'cmb10',
#  'STIXSizeOneSym',
#  'Cumberland AMT',
#  'Noto Sans KR',
#  'Georgia',
#  'ON Hwaryongdo',
#  'Calisto MT',
#  'Lucida Fax',
#  'Segoe UI',
#  'Nirmala UI',
#  'Gill Sans MT',
#  'Georgia',
#  'Symbol MT',
#  'Ebrima',
#  'Baskerville Old Face',
#  'Corbel',
#  'Courier New',
#  'Franklin Gothic Demi Cond',
#  'Bookman Old Style',
#  'Franklin Gothic Book',
#  'Palatino Linotype',
#  'Franklin Gothic Medium',
#  'Corbel',
#  'Avenir Next for SAS',
#  'NewJumja',
#  'Snap ITC',
#  'Gill Sans MT',
#  'Pyunji R',
#  'SimSun-ExtB',
#  'Magic R',
#  'Palace Script MT',
#  'Rockwell',
#  'Helvetica Neue for SAS',
#  'NanumSquare',
#  'Microsoft Sans Serif',
#  'Avenir Next for SAS',
#  'Corbel',
#  'Microsoft Uighur',
#  'Segoe UI',
#  'Calibri',
#  'MS Reference Sans Serif',
#  'Bradley Hand ITC',
#  'Albany AMT',
#  'Times New Roman',
#  'Gill Sans MT',
#  'Nirmala UI',
#  'Calisto MT',
#  'MingLiU-ExtB',
#  'Garamond',
#  'Times New Roman',
#  'Noto Sans JP',
#  'Poor Richard',
#  'Symbol',
#  'Wide Latin',
#  'Century',
#  'HyhwpEQ',
#  'Palace Script MT',
#  'Helvetica Neue for SAS',
#  'Cambria',
#  'Trebuchet MS',
#  'Microsoft Tai Le',
#  'HYHeadLine-Medium',
#  'NanumBarunpen',
#  'Segoe UI Symbol',
#  'Vivaldi',
#  'Calisto MT',
#  'Hancom Sans Light',
#  'HYGungSo-Bold',
#  'Malgun Gothic',
#  'Noto Sans JP',
#  'Hancom Sans SemiBold',
#  'Cumberland AMT',
#  'Tempus Sans ITC',
#  'Constantia',
#  'Microsoft New Tai Lue',
#  'Helvetica Neue for SAS',
#  'Centaur',
#  'HCR Batang ExtB',
#  'Trebuchet MS',
#  'Cumberland AMT',
#  'Goudy Stout',
#  'HYPMokGak-Bold',
#  'Britannic Bold',
#  'Binggrae Samanco',
#  'Yu Gothic',
#  'Perpetua',
#  'MV Boli',
#  'Wandocleansea',
#  'Georgia',
#  'Showcard Gothic',
#  'Arial',
#  'Rage Italic',
#  'Sitka Small',
#  'HoloLens MDL2 Assets',
#  'MS Outlook',
#  'Constantia',
#  'Corbel',
#  'Tw Cen MT',
#  'Noto Sans Thai',
#  'Franklin Gothic Medium',
#  'Noto Sans',
#  'Eras Bold ITC',
#  'Times New Roman Uni',
#  'Matura MT Script Capitals',
#  'Old English Text MT',
#  'HYGraphic-Medium',
#  'MingLiU',
#  'Lucida Sans',
#  'Felix Titling',
#  'Microsoft JhengHei',
#  'Goudy Old Style',
#  'Magneto',
#  'Verdana',
#  'Lucida Bright',
#  'Segoe Print',
#  'Rockwell',
#  'Avenir Next for SAS',
#  'Georgia',
#  'Cumberland AMT',
#  'Impact',
#  'Franklin Gothic Book',
#  'Candara',
#  'Franklin Gothic Medium Cond',
#  'Rockwell Extra Bold',
#  'Rage Italic',
#  'Kristen ITC',
#  'Trebuchet MS',
#  'Monotype Corsiva',
#  'Noto Sans KR',
#  'Lucida Sans',
#  'Gigi',
#  'Algerian',
#  'Lucida Fax',
#  'HYMyeongJo-Extra',
#  'Noto Sans TC',
#  'MoeumT R',
#  'HYPMokGak-Bold',
#  'Vivaldi',
#  'MingLiU',
#  'Brush Script MT',
#  'FontAwesome',
#  'Lucida Calligraphy',
#  'Microsoft YaHei',
#  'HCR Batang ExtB',
#  'Bodoni MT',
#  'Cambria',
#  'Script MT Bold',
#  'HoloLens MDL2 Assets',
#  'Haan Wing2',
#  'Magneto',
#  'Berlin Sans FB Demi',
#  'Colonna MT',
#  'Noto Sans TC',
#  'Franklin Gothic Demi',
#  'Leelawadee UI',
#  'Haettenschweiler',
#  'Nanum Brush Script',
#  'Informal Roman',
#  'NanumMyeongjo',
#  'Hancom Gothic',
#  'Hancom Hoonminjeongeum_V',
#  'MS Mincho',
#  'Verdana',
#  'Elephant',
#  'Corbel',
#  'Ebrima',
#  'Segoe UI',
#  'Arial Rounded MT Bold',
#  'Sylfaen',
#  'Symbol',
#  'Copperplate Gothic Bold',
#  'Viner Hand ITC',
#  'Gill Sans MT Ext Condensed Bold',
#  'Times New Roman Symbol',
#  'Gadugi',
#  'Dubai',
#  'HYPost-Light',
#  'Californian FB',
#  'Noto Sans Thai',
#  'Arial',
#  'Sitka Small',
#  'Hancom Gothic',
#  'Arial Symbol',
#  'Segoe UI',
#  'MV Boli',
#  'Comic Sans MS',
#  'Kristen ITC',
#  'Matura MT Script Capitals',
#  'HeiT',
#  'Batang',
#  'NanumSquare_ac',
#  'Script MT Bold',
#  'Trebuchet MS',
#  'Book Antiqua',
#  'Leelawadee UI',
#  'MT Extra',
#  'sas-icons',
#  'NanumSquare_ac',
#  'Agency FB',
#  'Verdana',
#  'Helvetica Neue for SAS',
#  'Malgun Gothic',
#  'NanumMyeongjo',
#  'Pristina',
#  'NanumBarunGothic',
#  'Eras Medium ITC',
#  'Comic Sans MS',
#  'Calibri',
#  'Yet R',
#  'Lucida Sans',
#  'Tw Cen MT Condensed',
#  'Gadugi',
#  'Century Schoolbook',
#  'Consolas',
#  'Haettenschweiler',
#  'Rockwell Condensed',
#  'Sitka Small',
#  'Tw Cen MT Condensed',
#  'Edwardian Script ITC',
#  'Constantia',
#  'Courier New',
#  'NewJumja',
#  'Sitka Small',
#  'Copperplate Gothic Bold',
#  'Segoe UI',
#  'Segoe UI',
#  'Cambria',
#  'HYPost-Medium',
#  'SAS Monospace',
#  'Wingdings 3',
#  'Calibri',
#  'Jokerman',
#  'pdficons',
#  'Berlin Sans FB',
#  'Niagara Solid',
#  'Segoe UI',
#  'sas-icons',
#  'NanumGothic',
#  'Microsoft JhengHei',
#  'Segoe UI',
#  'NanumBarunGothic',
#  'Century Gothic',
#  'Trebuchet MS',
#  'Candara',
#  'Albany AMT',
#  'Impact',
#  'Berlin Sans FB',
#  'Bodoni MT',
#  'Avenir Next for SAS',
#  'CSongGB18030C-Light',
#  'Segoe UI',
#  'Bodoni MT',
#  'Lucida Handwriting',
#  'SAS Monospace Bold',
#  'Albany AMT',
#  'New Gulim',
#  'Snap ITC',
#  'MoeumT R',
#  'Yu Gothic',
#  'Leelawadee',
#  'MS Outlook',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Dubai',
#  'Gabriola',
#  'Harrington',
#  'Harrington',
#  'Bodoni MT',
#  'Viner Hand ITC',
#  'Times New Roman Symbol',
#  'Times New Roman Symbol',
#  'Lucida Console',
#  'Jokerman',
#  'Harlow Solid Italic',
#  'Book Antiqua',
#  'Cumberland AMT',
#  'Arial',
#  'Blackadder ITC',
#  'Courier New',
#  'Symbola',
#  'Playbill',
#  'Constantia',
#  'Franklin Gothic Medium',
#  'Eras Medium ITC',
#  'Maiandra GD',
#  'Microsoft YaHei',
#  'Gloucester MT Extra Condensed',
#  'Engravers MT',
#  'Noto Sans JP',
#  'Tw Cen MT',
#  'Bookman Old Style',
#  'Microsoft JhengHei',
#  'Franklin Gothic Heavy',
#  'Candara',
#  'NanumBarunGothic',
#  'Lucida Bright',
#  'New Gulim',
#  'Wemakeprice',
#  'Mistral',
#  'Segoe UI Symbol',
#  'Consolas',
#  'SimSun',
#  'Bookman Old Style',
#  'Bodoni MT',
#  'NanumSquareRound',
#  'Tw Cen MT',
#  'NanumSquare',
#  'Century Gothic',
#  'Headline R',
#  'Elephant',
#  'HYPost-Light',
#  'Castellar',
#  'Lucida Fax',
#  'Eras Demi ITC',
#  'Symbola',
#  'Garamond',
#  'High Tower Text',
#  'Segoe MDL2 Assets',
#  'Cambria',
#  'Ebrima',
#  'Bodoni MT',
#  'Lucida Sans Typewriter',
#  'Wingdings',
#  'Cooper Black',
#  'Monotype Corsiva',
#  'Noto Sans SC',
#  'Noto Sans SC',
#  'Magic R',
#  'Arial Unicode MS',
#  'Segoe UI',
#  'Gill Sans MT Condensed',
#  'Sitka Small',
#  'Nirmala UI',
#  'Noto Sans KR',
#  'Microsoft YaHei',
#  'Consolas',
#  'Lucida Sans Typewriter',
#  'Tahoma',
#  'HYShortSamul-Medium',
#  'Binggrae Samanco',
#  'Verdana',
#  'Noto Sans',
#  'Palatino Linotype',
#  'Yu Gothic',
#  'Baskerville Old Face',
#  'Informal Roman',
#  'Avenir Next for SAS',
#  'Times New Roman Symbol',
#  'Californian FB',
#  'Forte',
#  'Candara',
#  'Perpetua',
#  'Franklin Gothic Demi',
#  'Times New Roman',
#  'Courier New',
#  'High Tower Text',
#  'Bodoni MT',
#  'Gill Sans Ultra Bold Condensed',
#  'Verdana',
#  'Helvetica Neue for SAS',
#  'HYGothic-Extra',
#  'Webdings',
#  'Palatino Linotype',
#  'Chiller',
#  'Haan Wing2',
#  'Lucida Sans',
#  'NanumSquareRound',
#  'CSongGB18030C-LightHWL',
#  'Bookshelf Symbol 7',
#  'Tw Cen MT',
#  'Lucida Console',
#  'Tempus Sans ITC',
#  'Gulim',
#  'Stencil',
#  'Colonna MT',
#  'Leelawadee UI',
#  'Headline R',
#  'Berlin Sans FB Demi',
#  'NanumSquare',
#  'Imprint MT Shadow',
#  'Segoe Print',
#  'Albany AMT',
#  'Goudy Old Style',
#  'Arial',
#  'Niagara Solid',
#  'Microsoft PhagsPa',
#  'Gong Gothic',
#  'Gadugi',
#  'Lucida Sans Unicode',
#  'Calisto MT',
#  'HCR Batang ExtB',
#  'HeiT',
#  'Noto Sans TC',
#  'Trebuchet MS',
#  'Garamond',
#  'Palatino Linotype',
#  'Goudy Stout',
#  'Yet R',
#  'Pyunji R',
#  'Verdana',
#  'Noto Sans SC',
#  'VITRO PRIDE TTF',
#  'Thorndale AMT',
#  'Bookman Old Style',
#  'Garamond',
#  'Gill Sans Ultra Bold',
#  'Lucida Sans Typewriter',
#  'Segoe UI',
#  'Microsoft PhagsPa',
#  'Bodoni MT',
#  'SAS Monospace Bold',
#  'Comic Sans MS',
#  'Old English Text MT',
#  'Century Schoolbook',
#  'Cambria',
#  'Broadway',
#  'Noto Sans',
#  'Corbel',
#  'Imprint MT Shadow',
#  'Corbel',
#  'Segoe UI',
#  'Brush Script MT',
#  'Onyx',
#  'Californian FB',
#  'Franklin Gothic Heavy',
#  'Malgun Gothic',
#  'Segoe Script',
#  'Consolas',
#  'Elephant',
#  'Hancom MalangMalang',
#  'Malgun Gothic',
#  'Rockwell',
#  'Corbel',
#  'Segoe UI Historic',
#  'Eras Light ITC',
#  'Leelawadee UI',
#  'Microsoft JhengHei',
#  'Noto Sans JP',
#  'Tw Cen MT',
#  'Arial',
#  'Albany AMT',
#  'Helvetica Neue for SAS',
#  'Eras Light ITC',
#  'Microsoft New Tai Lue',
#  'Palatino Linotype',
#  'Wingdings',
#  'LastResort',
#  'Segoe Script',
#  'Lucida Sans',
#  'Ami R',
#  'Curlz MT',
#  'Courier New',
#  'Thorndale AMT',
#  'Segoe MDL2 Assets',
#  'Franklin Gothic Demi',
#  'Myanmar Text',
#  'Lucida Sans Typewriter',
#  'MS Mincho',
#  'Georgia',
#  'HYGothic-Medium',
#  'Bodoni MT',
#  'Vladimir Script',
#  'KOAROO',
#  'MS Gothic',
#  'Candara',
#  'Yu Gothic',
#  'Arial',
#  'Ravie',
#  'Noto Sans Thai',
#  'Rockwell',
#  'Vladimir Script',
#  'Franklin Gothic Heavy',
#  'Perpetua Titling MT',
#  'NanumGothic',
#  'Freestyle Script',
#  'Century Gothic',
#  'Mistral',
#  'MT Extra',
#  'Curlz MT',
#  'Arial',
#  'Calibri',
#  'Perpetua Titling MT',
#  'HCR Dotum Ext',
#  'Helvetica Neue for SAS',
#  'Lucida Fax',
#  'Bodoni MT',
#  'Myanmar Text',
#  'Candara',
#  'Microsoft YaHei',
#  'Modern No. 20',
#  'Gill Sans MT Condensed',
#  'Lucida Sans Typewriter',
#  'Goudy Old Style',
#  'SAS Monospace',
#  'Leelawadee',
#  'Avenir Next for SAS',
#  'Lucida Bright',
#  'Wemakeprice',
#  'Leelawadee',
#  'Freestyle Script',
#  'Arial',
#  'ON Hwaryongdo',
#  'Microsoft Sans Serif',
#  'Ink Free',
#  'Book Antiqua',
#  'Franklin Gothic Book',
#  'Century Schoolbook',
#  'NanumSquare_ac',
#  'Segoe UI',
#  'Agency FB',
#  'Avenir Next for SAS',
#  'Franklin Gothic Demi Cond',
#  'Blackadder ITC',
#  'Yu Gothic',
#  'Segoe UI',
#  'CSongGB18030C-LightHWL',
#  'HYHeadLine-Medium',
#  'Footlight MT Light',
#  'Rockwell',
#  'Albany AMT',
#  'Gill Sans MT',
#  'Helvetica Neue for SAS',
#  'Nanum Pen Script',
#  'Arial',
#  'Bodoni MT',
#  'Arial',
#  'Bell MT',
#  'Dubai',
#  'Lucida Sans Typewriter',
#  'Tahoma',
#  'Lucida Sans',
#  'Comic Sans MS',
#  'Century Schoolbook',
#  'HCR Dotum Ext',
#  'Cumberland AMT',
#  'Constantia',
#  'Times New Roman',
#  'Noto Sans',
#  'Courier New',
#  'Calibri',
#  'NanumSquareRound',
#  'Segoe UI Emoji',
#  'Bauhaus 93',
#  'Calibri',
#  'Garamond',
#  'Noto Sans',
#  'Rockwell Condensed',
#  'HYMyeongJo-Extra',
#  'Microsoft Yi Baiti',
#  'Candara',
#  'BM Euljiro 10 years later',
#  'Comic Sans MS',
#  'Segoe UI',
#  'Georgia',
#  'General Kim Jwa-jin  Regular',
#  'HCR Batang Ext',
#  'Lucida Bright',
#  'Copperplate Gothic Light',
#  'Segoe UI',
#  'HCR Dotum',
#  'Kunstler Script',
#  'Thorndale AMT',
#  'Verdana',
#  'Cumberland AMT',
#  'Book Antiqua',
#  'Calibri',
#  'Noto Sans',
#  'Microsoft Uighur',
#  'Century Schoolbook',
#  'Onyx',
#  'Copperplate Gothic Light',
#  'Segoe UI',
#  'Noto Sans SC',
#  'Juice ITC',
#  'French Script MT',
#  'Gill Sans MT Ext Condensed Bold',
#  'Bookshelf Symbol 7',
#  'Engravers MT',
#  'Franklin Gothic Demi',
#  'Microsoft PhagsPa',
#  'HyhwpEQ',
#  'NanumSquare',
#  'Wemakeprice',
#  'Consolas',
#  'Lucida Fax',
#  'Gong Gothic',
#  'Gill Sans MT',
#  'Cooper Black',
#  'Elephant',
#  'Century Gothic',
#  'High Tower Text',
#  'Bookman Old Style',
#  'Sylfaen',
#  'Candara',
#  'Centaur',
#  'HCR Batang',
#  'Palatino Linotype',
#  'HCR Dotum',
#  'Consolas',
#  'Gill Sans Ultra Bold Condensed',
#  'Arial',
#  'Noto Sans',
#  'Comic Sans MS',
#  'Bodoni MT',
#  'Leelawadee UI',
#  'Lucida Bright',
#  'Hancom MalangMalang',
#  'Lucida Calligraphy',
#  'Wandohope',
#  'Microsoft YaHei',
#  'Calibri',
#  'Times New Roman',
#  'NanumGothic',
#  'Bell MT',
#  'NanumSquare_ac',
#  'Malgun Gothic',
#  'Thorndale AMT',
#  'Rockwell',
#  'Gill Sans MT',
#  'Albany AMT',
#  'Segoe UI',
#  'Microsoft PhagsPa',
#  'KOAROO',
#  'Rockwell Condensed',
#  'Franklin Gothic Medium',
#  'Corbel',
#  'Microsoft Uighur',
#  'Avenir Next for SAS',
#  'Goudy Old Style',
#  'Thorndale AMT',
#  'Juice ITC',
#  'Rockwell',
#  'Mongolian Baiti',
#  'Bodoni MT',
#  'Comic Sans MS',
#  'Bodoni MT',
#  'pdficons',
#  'Noto Sans SC',
#  'Dubai',
#  'Hancom Gothic',
#  'MS Reference Specialty',
#  'Segoe UI',
#  'Segoe UI Historic',
#  'Arial Symbol',
#  'Bodoni MT',
#  'Arial Symbol',
#  'Century Schoolbook',
#  'MYingHei_18030_C-MediumHWL',
#  'Noto Sans',
#  'Arial Symbol',
#  'Corbel',
#  'Lucida Bright',
#  'Arial',
#  'Berlin Sans FB',
#  'Lucida Bright',
#  'Trebuchet MS',
#  'Lucida Fax',
#  'HCR Batang',
#  'Courier New',
#  'Arial',
#  'Arial Unicode MS',
#  'Microsoft New Tai Lue',
#  'Avenir Next for SAS',
#  'Book Antiqua',
#  'Perpetua Titling MT',
#  'Franklin Gothic Heavy',
#  'Agency FB',
#  'Lucida Sans Unicode',
#  'HYGraphic-Medium',
#  'Monotype Sorts',
#  'Lucida Sans',
#  'Book Antiqua',
#  'Calisto MT',
#  'Thorndale AMT',
#  'Times New Roman',
#  'MYingHei_18030_C-MediumHWL',
#  'Parchment',
#  'Gill Sans MT',
#  'Tw Cen MT Condensed',
#  'Thorndale AMT',
#  'VITRO CORE TTF',
#  'Britannic Bold',
#  'Tw Cen MT',
#  'Microsoft Tai Le',
#  'Century Schoolbook',
#  'ON Hwaryongdo',
#  'Microsoft Yi Baiti',
#  'Leelawadee UI',
#  'Calisto MT',
#  'Footlight MT Light',
#  'Javanese Text',
#  'Perpetua',
#  'MS Reference Sans Serif',
#  'Wandohope',
#  'Segoe UI',
#  'High Tower Text',
#  'Bookman Old Style',
#  'Franklin Gothic Medium Cond',
#  'NanumGothic',
#  'Nirmala UI',
#  'HYShortSamul-Medium',
#  'Edwardian Script ITC',
#  'Tahoma',
#  'Batang',
#  'HCR Batang ExtB',
#  'Consolas',
#  'Tw Cen MT',
#  'Century Gothic',
#  'Rockwell',
#  'MingLiU-ExtB',
#  'Yu Gothic',
#  'Microsoft New Tai Lue',
#  'Noto Sans TC',
#  'Ebrima',
#  'Castellar',
#  'Corbel',
#  'Tw Cen MT',
#  'LastResort',
#  'FontAwesome',
#  'Microsoft JhengHei',
#  'Rockwell Condensed',
#  'Cumberland AMT',
#  'Chiller',
#  'Wide Latin',
#  'Dubai',
#  'Niagara Engraved',
#  'Noto Sans KR',
#  'Gulim',
#  'Arial Symbol',
#  'Verdana',
#  'Avenir Next for SAS',
#  'Nirmala UI',
#  'HYSinMyeongJo-Medium',
#  'Albany AMT',
#  'Calibri',
#  'Pristina',
#  'Microsoft Uighur',
#  'Bodoni MT',
#  'Tw Cen MT Condensed',
#  'HCR Dotum',
#  'MS Gothic',
#  'Arial Symbol',
#  'Perpetua Titling MT',
#  'HCR Batang',
#  'Gadugi',
#  'Perpetua',
#  'Calisto MT',
#  'Tw Cen MT Condensed Extra Bold',
#  'Segoe UI',
#  'Segoe UI',
#  'Calibri',
#  'Arial',
#  'Bauhaus 93',
#  'Noto Sans TC',
#  'Microsoft Himalaya',
#  'Georgia',
#  'Sitka Small',
#  'Maiandra GD',
#  'Century Gothic',
#  'Bell MT',
#  'HancomEQN',
#  'Californian FB',
#  'Candara',
#  'Comic Sans MS',
#  'Cambria',
#  'Times New Roman Symbol',
#  'Myanmar Text',
#  'Monotype Sorts',
#  'NanumBarunpen',
#  'HCR Batang',
#  'Gigi',
#  'Parchment',
#  'Yu Gothic',
#  'Hancom Gothic',
#  'CSongGB18030C-Light',
#  'OCR A Extended',
#  'Arial Rounded MT Bold',
#  'Felix Titling',
#  'HCR Batang Ext',
#  'Book Antiqua',
#  'Lucida Sans Typewriter',
#  'Tahoma',
#  'Ravie',
#  'Constantia',
#  'Microsoft JhengHei',
#  'Marlett',
#  'Algerian',
#  'Mongolian Baiti',
#  'Bell MT',
#  'Palatino Linotype',
#  'Microsoft Tai Le',
#  'Courier New',
#  'Times New Roman',
#  'Segoe UI',
#  'HYGungSo-Bold',
#  'Century Gothic',
#  'Yydimibang',
#  'Perpetua',
#  'Lucida Bright',
#  'Times New Roman',
#  'Ink Free',
#  'Modern No. 20',
#  'Noto Sans KR',
#  'Cambria',
#  'Dubai',
#  'Century Gothic',
#  'Berlin Sans FB',
#  'Agency FB',
#  'Times New Roman Uni',
#  'Kunstler Script',
#  'Stencil',
#  'Gloucester MT Extra Condensed',
#  'HYPost-Medium',
#  'NanumSquareRound',
#  'Segoe UI Emoji',
#  'Constantia',
#  'Wingdings 3',
#  'Californian FB',
#  'Gong Gothic',
#  'Perpetua',
#  'Bahnschrift',
#  'Papyrus',
#  'Microsoft YaHei',
#  'Goudy Old Style',
#  'Wandocleansea',
#  'Candara',
#  'Consolas',
#  'Noto Sans Thai',
#  'Bahnschrift',
#  'Noto Sans SC',
#  'Webdings',
#  'Sitka Small',
#  'Constantia',
#  'Bernard MT Condensed',
#  'Eras Demi ITC',
#  'Segoe Script',
#  'Segoe Print',
#  'Century',
#  'Noto Sans JP',
#  'Papyrus',
#  'Segoe Script',
#  'Lucida Sans Typewriter',
#  'Noto Sans KR',
#  'Eras Bold ITC',
#  'NanumMyeongjo',
#  'Arial',
#  'Ami R',
#  'Lucida Handwriting',
#  'Thorndale AMT',
#  'Calisto MT',
#  'Microsoft Himalaya',
#  'Showcard Gothic',
#  'Rockwell Extra Bold',
#  'Candara',
#  'Dubai',
#  'KOTRA_BOLD',
#  'Perpetua',
#  'Calibri',
#  'Segoe UI',
#  'Noto Sans JP',
#  'Bernard MT Condensed',
#  'Tw Cen MT Condensed Extra Bold',
#  'General Kim Jwa-jin Bold',
#  'Niagara Engraved',
#  'MARU Buri Beta',
#  'Arial',
#  'Cambria',
#  'Book Antiqua',
#  'Helvetica Neue for SAS',
#  'Bell MT',
#  'Javanese Text',
#  'Malgun Gothic',
#  'Noto Sans TC',
#  'Symbol MT',
#  'Georgia',
#  'NanumBarunGothic',
#  'Microsoft Tai Le',
#  'Trebuchet MS',
#  'Yu Gothic',
#  'French Script MT',
#  'SimSun',
#  'Nirmala UI',
#  'Wingdings 2',
#  'Avenir Next for SAS',
#  'Bodoni MT',
#  'Poor Richard',
#  'Franklin Gothic Book',
#  'SimSun-ExtB',
#  'Helvetica Neue for SAS',
#  'Harlow Solid Italic',
#  'HancomEQN',
#  'HCR Dotum',
#  'HYGothic-Extra',
#  'Arial Symbol',
#  'Arial',
#  'Myanmar Text',
#  'Perpetua',
#  'OCR A Extended',
#  'ROH HOE-CHAN',
#  'Goudy Old Style',
#  'Wingdings 2',
#  'Garamond',
#  'Helvetica Neue for SAS',
#  'Gabriola',
#  'Bodoni MT',
#  'Bell MT',
#  'Times New Roman Symbol',
#  'Candara',
#  'Gill Sans Ultra Bold',
#  'Calibri',
#  'Arial',
#  'HYSinMyeongJo-Medium',
#  'Bradley Hand ITC',
#  'MYingHei_18030_C-Medium',
#  'Segoe Print',
#  'Century Schoolbook',
#  'Sitka Small',
#  'Times New Roman Symbol',
#  'HYGothic-Medium',
#  'KOAROO',
#  'Bookman Old Style',
#  'Gill Sans MT',
#  'Corbel',
#  'Bookman Old Style',
#  'Dubai',
#  'MYingHei_18030_C-Medium',
#  'Playbill',
#  'Bodoni MT',
#  'Helvetica Neue for SAS',
#  'Lucida Fax',
#  'Lucida Sans',
#  'Leelawadee',
#  'Times New Roman Symbol',
#  'Forte',
#  'Lucida Fax',
#  'MS Reference Specialty',
#  'Californian FB',
#  'Palatino Linotype',
#  'Avenir Next for SAS',
#  'Broadway',
#  'Arial Symbol']

# %%
plt.rc('font', family='NanumSquare_ac')
fig,axs=plt.subplots(figsize=(20,20))
corr = data.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, 
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            mask=mask,
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\User\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
